# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAhmadIshtiaq/ml-internship-muhammadahmadishtiaq/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MuhammadAhmadIshtiaq/ml-internship-muhammadahmadishtiaq/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# !git clone https://github.com/MuhammadAhmadIshtiaq/ml-internship-muhammadahmadishtiaq.git
# %cd ml-internship-muhammadahmadishtiaq
# Out:
# Cloning into 'ml-internship-muhammadahmadishtiaq'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 124 (delta 38), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.85 MiB | 6.08 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/ml-internship-muhammadahmadishtiaq/ml-internship-muhammadahmadishtiaq/ml-internship-muhammadahmadishtiaq/ml-internship-muhammadahmadishtiaq

# %% [markdown]
# I'm going with the content refresh / declining pages lane. Pages that ranked well before can quietly lose traffic over time, and catching that early feels like a useful, real problem worth digging into.:

# %%
# This cell is for CODE (numbers, a query, a check).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This helps decide which pages a content team should review first. It's for people managing lots of content who can't check every page by hand. If the call is wrong, they either waste time reviewing a fine page, or miss a page that's actually slipping and it keeps losing traffic unnoticed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# This sample has 30,000 pages across 44 columns. Over half — about 54% — are trending down, while only about 15% are trending up and 20% are holding stable. That's a strong sign this lane is worth pursuing: more than half the pages here are quietly losing ground, which is exactly the kind of thing a content team would want a way to catch early and prioritize.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows, columns:", df.shape)
print(df["trend_direction"].value_counts(normalize=True))
# Out:
# Rows, columns: (30000, 44)
# trend_direction
# down      0.542067
# stable    0.198733
# up        0.146267
# new       0.074533
# flat      0.038400
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This can say what the data shows and point toward pages worth checking first. It's meant to support a human's decision, not replace it. It can't prove what caused a page to decline, and it's not predicting how Google's algorithm actually works.

# %% [markdown]
# With 30,000+ pages and more added over time, no team can manually review every page regularly — that's exactly the kind of scale problem where a data-driven scoring signal helps, by surfacing the pages most likely to need attention instead of relying on guesswork or checking pages at random.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
